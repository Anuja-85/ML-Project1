# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
from keras.models import Sequential
from keras.layers import LSTM, Dense,Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
import yfinance as yf

# %%
start = '2013-08-31'
end = '2023-07-30'

try:
    df = yf.download('AAPL', start=start, end=end)
    df.head()
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df = yf.download('AAPL', start=start, end=end)
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2013-09-03  17.610714  17.878571  17.405357  17.449286  15.228884  331928800
# 2013-09-04  17.841429  17.937143  17.724285  17.810356  15.544011  345032800
# 2013-09-05  17.866072  17.881430  17.629999  17.688213  15.437405  236367600
# 2013-09-06  17.801430  17.834999  17.498215  17.793571  15.529358  359525600
# 2013-09-09  18.035713  18.139999  17.981428  18.077499  15.777156  340687200

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-24  193.410004  194.910004  192.250000  192.750000  192.490067
# 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.358887
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  194.237701
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  192.959427
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  195.565918
#
#               Volume
# Date
# 2023-07-24  45377800
# 2023-07-25  37283200
# 2023-07-26  47471900
# 2023-07-27  47460200
# 2023-07-28  48291400

# %%
fig_size = (12,6)
plt.figure(figsize=fig_size)
plt.plot(df.index, df['Close'])

plt.title('Close Price History')
#plt.plot(df['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=18)
plt.show()

# %%
df = df.reset_index()
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2013-09-03  17.610714  17.878571  17.405357  17.449286  15.228884  331928800
# 1 2013-09-04  17.841429  17.937143  17.724285  17.810356  15.544011  345032800
# 2 2013-09-05  17.866072  17.881430  17.629999  17.688213  15.437405  236367600
# 3 2013-09-06  17.801430  17.834999  17.498215  17.793571  15.529358  359525600
# 4 2013-09-09  18.035713  18.139999  17.981428  18.077499  15.777156  340687200

# %%
df = df.drop(['Date','Adj Close'],axis=1)
df
# Out:
#             Open        High         Low       Close     Volume
# 0      17.610714   17.878571   17.405357   17.449286  331928800
# 1      17.841429   17.937143   17.724285   17.810356  345032800
# 2      17.866072   17.881430   17.629999   17.688213  236367600
# 3      17.801430   17.834999   17.498215   17.793571  359525600
# 4      18.035713   18.139999   17.981428   18.077499  340687200
# ...          ...         ...         ...         ...        ...
# 2488  193.410004  194.910004  192.250000  192.750000   45377800
# 2489  193.330002  194.440002  192.919998  193.619995   37283200
# 2490  193.669998  195.639999  193.320007  194.500000   47471900
# 2491  196.020004  197.199997  192.550003  193.220001   47460200
# 2492  194.669998  196.630005  194.139999  195.830002   48291400
#
# [2493 rows x 5 columns]

# %%
df.Close.plot()
# Out:
# <Axes: >

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 2488    172.4232
# 2489    172.9063
# 2490    173.3922
# 2491    173.8141
# 2492    174.2341
# Name: Close, Length: 2493, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2488    157.70575
# 2489    157.94185
# 2490    158.18720
# 2491    158.45285
# 2492    158.72990
# Name: Close, Length: 2493, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')

# %%
df.shape
# Out:
# (2493, 5)

# %%
close= df['Close']
X= close.values
X
# Out:
# array([ 17.44928551,  17.81035614,  17.68821335, ..., 194.5       ,
#        193.22000122, 195.83000183])

# %%
X_shaped=X.reshape(-1,1)

scalar= MinMaxScaler(feature_range=(0,1))
X_scaled=scalar.fit_transform(X_shaped)
X_scaled
# Out:
# array([[0.00764138],
#        [0.00965007],
#        [0.00897057],
#        ...,
#        [0.992601  ],
#        [0.98548018],
#        [1.        ]])

# %%
print(len(X_scaled))
thresh= int(len(X)*.8)
thresh
# Out:
# 2493
# 1994

# %%
train_data = X_scaled[:thresh,:]
xtrain=[]
ytrain=[]
for i in range(100,len(train_data)):
    xtrain.append(train_data[i-100:i,0])
    ytrain.append(train_data[i,0])
ytrain[:20]

# %%
x = df

# %%
# Spliting Data into Training and Testing

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_splitin_test_split()
